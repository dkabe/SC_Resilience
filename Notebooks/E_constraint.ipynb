# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import multiprocessing as mp

# %% [markdown]
# ## Two Objectives

# %%
# Covid product instance - 95% rl

# %%
payoff_table = np.array([[0, 126708641.91], 
                         [18932218.87, 4549.09]])

# %%
lb = [np.asarray(payoff_table)[i][i] for i in range(payoff_table.shape[0])]
ub = [np.max(payoff_table[:,i]) for i in range(payoff_table.shape[1])]

# %%
resolution = 20
mesh_refine = [resolution]*len(lb)
linsp = [np.linspace(lb[l], ub[l], mesh_refine[l]) for l in range(len(lb))]

# %%
np.savetxt('/home/dkabe/Model_brainstorming/Epsilon_Constraint/Two_Objectives/Instance_1/Ranges/0.95_ranges.txt', linsp)

# %%
linsp
# Out:
# [array([       0.        ,   996432.57210526,  1992865.14421053,
#          2989297.71631579,  3985730.28842105,  4982162.86052632,
#          5978595.43263158,  6975028.00473684,  7971460.57684211,
#          8967893.14894737,  9964325.72105263, 10960758.2931579 ,
#         11957190.86526316, 12953623.43736842, 13950056.00947369,
#         14946488.58157895, 15942921.15368421, 16939353.72578948,
#         17935786.29789474, 18932218.87      ]),
#  array([4.54909000e+03, 6.67318555e+06, 1.33418220e+07, 2.00104585e+07,
#         2.66790949e+07, 3.33477314e+07, 4.00163679e+07, 4.66850043e+07,
#         5.33536408e+07, 6.00222773e+07, 6.66909137e+07, 7.33595502e+07,
#         8.00281867e+07, 8.66968231e+07, 9.33654596e+07, 1.00034096e+08,
#         1.06702733e+08, 1.13371369e+08, 1.20040005e+08, 1.26708642e+08])]

# %%
# Covid product instance - 75% rl

# %%
payoff_table = np.array([[0, 113712883.76], 
                         [18932219.22, 3450.95]])

# %%
lb = [np.asarray(payoff_table)[i][i] for i in range(payoff_table.shape[0])]
ub = [np.max(payoff_table[:,i]) for i in range(payoff_table.shape[1])]

# %%
resolution = 20
mesh_refine = [resolution]*len(lb)
linsp = [np.linspace(lb[l], ub[l], mesh_refine[l]) for l in range(len(lb))]

# %%
np.savetxt('/home/dkabe/Model_brainstorming/Epsilon_Constraint/Two_Objectives/Instance_1/Ranges/0.75_ranges.txt', linsp)

# %%
# Covid product instance - 50% rl

# %%
payoff_table = np.array([[0, 97468186.08], 
                         [18932216.09, 3450.95]])

# %%
lb = [np.asarray(payoff_table)[i][i] for i in range(payoff_table.shape[0])]
ub = [np.max(payoff_table[:,i]) for i in range(payoff_table.shape[1])]

# %%
resolution = 20
mesh_refine = [resolution]*len(lb)
linsp = [np.linspace(lb[l], ub[l], mesh_refine[l]) for l in range(len(lb))]

# %%
np.savetxt('/home/dkabe/Model_brainstorming/Epsilon_Constraint/Two_Objectives/Instance_1/Ranges/0.5_ranges.txt', linsp)

# %%
rl = [0.5, 0.75, 0.95]
x_list = []
y_list = []

# %%
for r_level in rl:
    data = np.loadtxt('/home/dkabe/Model_brainstorming/Epsilon_Constraint/Two_Objectives/Instance_1/e_cons_results_' + str(r_level) + '.txt')
    x = data[:,0]
    y = data[:,1]
    plt.plot(x, y, 'ro')
    plt.xlabel("Cost of met demand")
    plt.ylabel("Cost of unmet demand")
    plt.show()
    x_list.append(x)
    y_list.append(y)

# %%
plt.scatter(x_list[0], y_list[0], label = 'rl at 0.5')
plt.scatter(x_list[1], y_list[1], label = 'rl at 0.75')
plt.scatter(x_list[2], y_list[2], label = 'rl at 0.95')
plt.xlabel("Cost of met demand")
plt.ylabel("Cost of unmet demand")
plt.legend()
plt.show()

# %% [markdown]
# ## Three Objectives

# %%
# Covid product instance - 50% rl

# %%
payoff_table = np.loadtxt("/home/dkabe/Model_brainstorming/Epsilon_Constraint/Three_Objectives/Instance_1/payoff_table_1_0.5.txt")

# %%
lb = [np.asarray(payoff_table)[i][i] for i in range(payoff_table.shape[0])]
ub = [np.max(payoff_table[:,i]) for i in range(payoff_table.shape[1])]

# %%
resolution = 20
mesh_refine = [resolution]*len(lb)
linsp = [np.linspace(lb[l], ub[l], mesh_refine[l]) for l in range(len(lb))]

# %%
np.savetxt('/home/dkabe/Model_brainstorming/Epsilon_Constraint/Three_Objectives/Instance_1/Ranges/0.5_ranges.txt', linsp)

# %%
# Meat product instance - 50% rl

# %%
payoff_table = np.loadtxt("/home/dkabe/Model_brainstorming/Epsilon_Constraint/Three_Objectives/Instance_2/payoff_table_2_0.5.txt")
lb = [np.asarray(payoff_table)[i][i] for i in range(payoff_table.shape[0])]
ub = [np.max(payoff_table[:,i]) for i in range(payoff_table.shape[1])]
resolution = 20
mesh_refine = [resolution]*len(lb)
linsp = [np.linspace(lb[l], ub[l], mesh_refine[l]) for l in range(len(lb))]
np.savetxt('/home/dkabe/Model_brainstorming/Epsilon_Constraint/Three_Objectives/Instance_2/Ranges/0.5_ranges.txt', linsp)

# %%
linsp
# Out:
# [array([       0.        ,  1201042.84210526,  2402085.68421053,
#          3603128.52631579,  4804171.36842105,  6005214.21052632,
#          7206257.05263158,  8407299.89473684,  9608342.73684211,
#         10809385.57894737, 12010428.42105263, 13211471.26315789,
#         14412514.10526316, 15613556.94736842, 16814599.78947368,
#         18015642.63157895, 19216685.47368421, 20417728.31578947,
#         21618771.15789474, 22819814.        ]),
#  array([       0.        ,  1959910.10526316,  3919820.21052632,
#          5879730.31578947,  7839640.42105263,  9799550.52631579,
#         11759460.63157895, 13719370.73684211, 15679280.84210526,
#         17639190.94736842, 19599101.05263158, 21559011.15789474,
#         23518921.2631579 , 25478831.36842106, 27438741.47368421,
#         29398651.57894737, 31358561.68421053, 33318471.78947369,
#         35278381.89473684, 37238292.        ]),
#  array([1.65410000e+05, 8.52836126e+06, 1.68913125e+07, 2.52542638e+07,
#         3.36172151e+07, 4.19801663e+07, 5.03431176e+07, 5.87060688e+07,
#         6.70690201e+07, 7.54319714e+07, 8.37949226e+07, 9.21578739e+07,
#         1.00520825e+08, 1.08883776e+08, 1.17246728e+08, 1.25609679e+08,
#         1.33972630e+08, 1.42335581e+08, 1.50698533e+08, 1.59061484e+08])]

# %% [markdown]
# ## Graphs

# %%
data = np.loadtxt("/home/dkabe/Model_brainstorming/Epsilon_Constraint/Three_Objectives/Instance_1/e_cons_results_0.5.txt")

# %%
data = data[334:]

# %%
x = data[:,0]
y = data[:,1]
z = data[:,2]

# %%
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection='3d')
ax.set_xlabel("Lost Sales + Penalties", fontsize = 12)
ax.set_ylabel("Outsourcing", fontsize = 12)
ax.set_zlabel("Inhouse costs", fontsize = 12)
ax.scatter3D(z,y,x)
plt.savefig("/home/dkabe/Model_brainstorming/Images/Instance_1/3dplot.png",bbox_inches = "tight")
plt.show()

# %%
plt.scatter(y,z)
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Lost Sales + Penalties")
#plt.title("Outsourcing vs. Lost Sales + Penalties")
plt.savefig("/home/dkabe/Model_brainstorming/Images/Instance_1/ols.png")
plt.show()

# %%
plt.scatter(x,z)
plt.xlabel("Inhouse Cost")
plt.ylabel("Cost of Lost Sales + Penalties")
#plt.title("Inhouse vs. Lost Sales + Penalties")
plt.savefig("/home/dkabe/Model_brainstorming/Images/Instance_1/ils.png")
plt.show()

# %%
plt.scatter(x,y)
plt.xlabel("Inhouse Cost")
plt.ylabel("Cost of Outsourcing")
#plt.title("Inhouse vs. Outsourcing")
plt.savefig("/home/dkabe/Model_brainstorming/Images/Instance_1/io.png")
plt.show()

# %%
# v2

# %%
data = np.loadtxt("/home/dkabe/Model_brainstorming/Epsilon_Constraint/Three_Objectives/Instance_2/e_cons_results_0.5.txt")

# %%
x = data[:,0]
y = data[:,1]
z = data[:,2]

# %%
fig = plt.figure(figsize = (6,6))
ax = plt.axes(projection='3d')
ax.set_xlabel("Lost Sales + Penalties", fontsize = 12)
ax.set_ylabel("Outsourcing", fontsize = 12)
ax.set_zlabel("Inhouse costs", fontsize = 12)
ax.scatter3D(z,y,x)
plt.savefig("/home/dkabe/Model_brainstorming/Images/Instance_2/3dplot.png", bbox_inches = "tight")
plt.show()

# %%
plt.scatter(y,z)
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Lost Sales + Penalties")
#plt.title("Outsourcing vs. Lost Sales + Penalties")
plt.savefig("/home/dkabe/Model_brainstorming/Images/Instance_2/ols.png")
plt.show()

# %%
plt.scatter(x,z)
plt.xlabel("Inhouse Cost")
plt.ylabel("Cost of Lost Sales + Penalties")
#plt.title("Inhouse vs. Lost Sales + Penalties")
plt.savefig("/home/dkabe/Model_brainstorming/Images/Instance_2/ils.png")
plt.show()

# %%
plt.scatter(x,y)
plt.xlabel("Inhouse Cost")
plt.ylabel("Cost of Outsourcing")
#plt.title("Inhouse vs. Outsourcing")
plt.savefig("/home/dkabe/Model_brainstorming/Images/Instance_2/io.png")
plt.show()
