# %%
import math
import numpy as np
import pandas as pd
from random import seed
import matplotlib.pyplot as plt

# %%
path = "/home/dkabe/Model_brainstorming/"

# %%
df = pd.read_csv(path + 'Output/results.txt', delimiter = "\t", header=None)

# %%
df = df[16:]

# %%
df
# Out:
#               0            1           2           3          4         5  \
# 26  32645158.95  26125681.57  2560308.81  3959168.13       0.44  0.959661
# 27  32699520.03  26125443.44  3002745.59  3571330.54       0.48  0.963603
# 28  32759597.53  26125226.11  3449526.99  3179681.68    5162.77  0.967618
# 29  32869736.16  26125581.98  3889474.77  2823984.06   30695.34  0.971353
# 30  33024039.65  26126504.14  4239919.93  2575884.64   81730.96  0.974170
# 31  33186631.92  26127701.52  4568586.50  2346902.65  143441.19  0.976822
# 32  33368842.16  26128217.26  4832546.69  2170005.34  238072.85  0.978992
# 33  33560133.61  29738951.40  2738387.92   911143.29  171651.21  0.991011
# 34  33662279.01  29738873.57  2924038.70   766867.88  232499.09  0.992543
# 35  33767363.95  29739691.49  3079837.86   657848.11  289986.72  0.993805
#
#            6    7    8           9
# 26  0.023123  3.0  3.0   18.836674
# 27  0.027065  3.0  3.0   41.595557
# 28  0.031080  3.0  3.0   48.346086
# 29  0.034763  3.0  3.0   53.059226
# 30  0.037469  3.0  3.0   63.869060
# 31  0.040024  3.0  3.0   71.963171
# 32  0.042138  3.0  3.0   78.269521
# 33  0.024543  4.0  3.0   88.421958
# 34  0.026086  4.0  3.0   96.488873
# 35  0.027315  4.0  3.0  100.343237

# %%
rl = [0.5 , 0.55, 0.6 , 0.65, 0.7, 0.75, 0.8 , 0.85, 0.9 , 0.95]
Obj = df[0]
InHouse = df[1]
Outsource = df[2]
LostSales = df[3]
RL_Penalties = df[4]

# %%
## Costs against different Recovery Levels

# %%
plt.plot(rl, Obj)
plt.title("Recovery Level vs. Total Cost")
plt.xlabel("Recovery Level")
plt.ylabel("Total Cost")
plt.show()

# %%
plt.plot(rl, InHouse)
plt.title("Recovery Level vs. In House Cost")
plt.xlabel("Recovery Level")
plt.ylabel("In House Cost")
plt.show()

# %%
plt.plot(rl, Outsource)
plt.title("Recovery Level vs. Cost of Outsourcing")
plt.xlabel("Recovery Level")
plt.ylabel("Cost of Outsourcing")
plt.show()

# %%
plt.plot(rl, LostSales)
plt.title("Recovery Level vs. Cost of Lost Sales")
plt.xlabel("Recovery Level")
plt.ylabel("Cost of Lost Sales")
plt.show()

# %%
plt.plot(rl, RL_Penalties)
plt.title("Recovery Level vs. Penalties")
plt.xlabel("Recovery Level")
plt.ylabel("Penalties")
plt.show()

# %%
## Costs against each other

# %%
plt.scatter(Outsource, LostSales)
plt.title("Cost of Outsourcing vs. Cost of Lost Sales")
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Lost Sales")
plt.show()

# %%
plt.scatter(Outsource, RL_Penalties)
plt.title("Cost of Outsourcing vs. Penalties")
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Penalties")
plt.show()

# %%
plt.scatter(LostSales, RL_Penalties)
plt.title("Cost of Lost Sales vs. Penalties")
plt.xlabel("Cost of Lost Sales")
plt.ylabel("Cost of Penalties")
plt.show()
