# %%
import math
import numpy as np
import pandas as pd
from random import seed
import matplotlib.pyplot as plt

# %%
path = "/home/dkabe/Model_brainstorming/"

# %%
df = pd.read_csv(path + 'Output/results.txt', delimiter = "\t", header=None)

# %%
df = df[16:]

# %%
df
# Out:
#               0            1           2           3          4         5  \
# 16  32579500.68  26125680.68  2494651.70  3959167.87       0.42  0.959661
# 17  32627040.99  26125443.66  2930277.79  3571319.09       0.46  0.963603
# 18  32684804.02  26125226.04  3374744.62  3179670.63    5162.75  0.967618
# 19  32766205.78  26125563.32  3801553.40  2808393.68   30695.34  0.971480
# 20  32865692.07  26126182.40  4195158.85  2462619.98   81730.83  0.975088
# 21  32990080.52  26126921.03  4583786.46  2135931.94  143441.06  0.978532
# 22  33147720.91  26126935.05  4918915.25  1863797.81  238072.82  0.981473
# 23  33358220.66  26126065.88  5084352.99  1739006.17  408795.58  0.982973
# 24  33537245.66  29738859.59  2803752.74   762134.51  232499.05  0.992582
# 25  33639822.74  29739690.27  2952515.55   657630.48  289986.69  0.993807
#
#            6    7    8          9
# 16  0.023123  3.0  3.0  14.233435
# 17  0.027065  3.0  3.0  36.518181
# 18  0.031080  3.0  3.0  40.310133
# 19  0.034900  3.0  3.0  48.001165
# 20  0.038459  3.0  3.0  55.982373
# 21  0.041870  3.0  3.0  61.327220
# 22  0.044816  3.0  3.0  68.156306
# 23  0.046339  3.0  3.0  78.471766
# 24  0.026127  4.0  3.0  84.469101
# 25  0.027316  4.0  3.0  92.604612

# %%
rl = [0.5 , 0.55, 0.6 , 0.65, 0.7, 0.75, 0.8 , 0.85, 0.9 , 0.95]
Outsource = df[2]
LostSales = df[3]
RL_Penalties = df[4]

# %%
## Costs against different Recovery Levels

# %%
plt.plot(rl, Outsource)
plt.title("Recovery Level vs. Cost of Outsourcing")
plt.xlabel("Recovery Level")
plt.ylabel("Cost of Outsourcing")
plt.show()

# %%
plt.plot(rl, LostSales)
plt.title("Recovery Level vs. Cost of Lost Sales")
plt.xlabel("Recovery Level")
plt.ylabel("Cost of Lost Sales")
plt.show()

# %%
plt.plot(rl, RL_Penalties)
plt.title("Recovery Level vs. Penalties")
plt.xlabel("Recovery Level")
plt.ylabel("Penalties")
plt.show()

# %%
## Costs against each other

# %%
plt.scatter(Outsource, LostSales)
plt.title("Cost of Outsourcing vs. Cost of Lost Sales")
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Lost Sales")
plt.show()

# %%
plt.scatter(Outsource, RL_Penalties)
plt.title("Cost of Outsourcing vs. Penalties")
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Penalties")
plt.show()

# %%
plt.scatter(LostSales, RL_Penalties)
plt.title("Cost of Lost Sales vs. Penalties")
plt.xlabel("Cost of Lost Sales")
plt.ylabel("Cost of Penalties")
plt.show()
