# %%
import math
import numpy as np
import pandas as pd
from random import seed
import matplotlib.pyplot as plt

# %%
path = "/home/dkabe/Model_brainstorming/"

# %%
## Instance 1

# %%
df = pd.read_csv(path + 'Output/results.txt', delimiter = "\t", header=None)

# %%
df = df[36:46]

# %%
df
# Out:
#               0            1           2           3        4         5  \
# 36  18595423.02  15415959.47   604811.24  2574651.79     0.00  0.943925
# 37  18618890.55  15529125.15   754348.50  2335416.51     0.00  0.949119
# 38  18648127.32  15528994.83  1035109.78  2084022.35     0.00  0.954589
# 39  18678758.51  15528806.31  1324398.21  1825553.64     0.00  0.960233
# 40  18710330.44  15528678.25  1609512.67  1572139.21     0.00  0.965795
# 41  18742033.99  15528603.66  1894794.08  1318635.95     0.00  0.971358
# 42  18774734.90  15528518.07  2176884.62  1069331.87     0.00  0.976854
# 43  18811055.93  15528419.05  2466702.54   815933.94     0.00  0.982415
# 44  18850450.09  15528249.32  2771669.38   550531.04     0.00  0.988170
# 45  18891751.55  15528051.17  3081878.39   280723.50  1098.14  0.994002
#
#            6    7    8          9
# 36  0.011457  3.0  4.0   5.322929
# 37  0.014299  3.0  4.0  14.839044
# 38  0.019769  3.0  4.0  16.965526
# 39  0.025410  3.0  4.0  17.772028
# ...

# %%
rl = [0.5 , 0.55, 0.6 , 0.65, 0.7, 0.75, 0.8 , 0.85, 0.9 , 0.95]

# %%
Obj = df[0]
InHouse = df[1]
Outsource = df[2]
LostSales = df[3]
RL_Penalties = df[4]

# %%
## Costs against different Recovery Levels

# %%
plt.plot(rl, Obj)
plt.title("Recovery Level vs. Total Cost")
plt.xlabel("Recovery Level")
plt.ylabel("Total Cost")
plt.show()

# %%
#plt.plot(rl, InHouse)
#plt.title("Recovery Level vs. In House Cost")
#plt.xlabel("Recovery Level")
#plt.ylabel("In House Cost")
#plt.show()

# %%
plt.plot(rl, Outsource)
plt.title("Recovery Level vs. Cost of Outsourcing")
plt.xlabel("Recovery Level")
plt.ylabel("Cost of Outsourcing")
plt.show()

# %%
plt.plot(rl, LostSales)
plt.title("Recovery Level vs. Cost of Lost Sales")
plt.xlabel("Recovery Level")
plt.ylabel("Cost of Lost Sales")
plt.show()

# %%
plt.plot(rl, RL_Penalties)
plt.title("Recovery Level vs. Penalties")
plt.xlabel("Recovery Level")
plt.ylabel("Penalties")
plt.show()

# %%
## Costs against each other

# %%
plt.scatter(Outsource, LostSales)
plt.title("Cost of Outsourcing vs. Cost of Lost Sales")
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Lost Sales")
plt.show()

# %%
plt.scatter(Outsource, RL_Penalties)
plt.title("Cost of Outsourcing vs. Penalties")
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Penalties")
plt.show()

# %%
plt.scatter(LostSales, RL_Penalties)
plt.title("Cost of Lost Sales vs. Penalties")
plt.xlabel("Cost of Lost Sales")
plt.ylabel("Cost of Penalties")
plt.show()

# %%
## Instance 2

# %%
path = "/home/dkabe/Model_brainstorming/"

# %%
df = pd.read_csv(path + 'Output/results.txt', delimiter = "\t", header=None)

# %%
df = df[46:]

# %%
df
# Out:
#               0            1           2           3          4         5  \
# 46  17998176.08  15627793.83   490236.72  1821988.85   58156.90  0.979304
# 47  18043178.40  15627807.19   586982.58  1752844.42   75544.44  0.980184
# 48  18104697.91  15627621.73   717704.61  1666439.71   92932.05  0.981446
# 49  18169508.53  15627501.62   871876.95  1559810.51  110319.65  0.982902
# 50  18237293.23  15627293.93  1037053.92  1445231.91  127713.69  0.984397
# 51  18317499.62  15626417.02  1179211.83  1356035.29  155835.70  0.985517
# 52  18410584.19  15625312.30  1272114.22  1317110.94  196046.93  0.986133
# 53  18507505.91  15624851.00  1356415.56  1255864.41  270375.15  0.986890
# 54  18604962.73  15625635.10  1614295.17  1017984.79  347047.92  0.989314
# 55  18710354.74  15626325.00  1874303.71   782823.00  426903.27  0.991737
#
#            6    7    8           9
# 46  0.004471  4.0  3.0   15.463182
# 47  0.005375  4.0  3.0   35.414876
# 48  0.006676  4.0  3.0   40.387149
# ...

# %%
Obj = df[0]
InHouse = df[1]
Outsource = df[2]
LostSales = df[3]
RL_Penalties = df[4]

# %%
## Costs against different Recovery Levels

# %%
plt.plot(rl, Obj)
plt.title("Recovery Level vs. Total Cost")
plt.xlabel("Recovery Level")
plt.ylabel("Total Cost")
plt.show()

# %%
#plt.plot(rl, InHouse)
#plt.title("Recovery Level vs. In House Cost")
#plt.xlabel("Recovery Level")
#plt.ylabel("In House Cost")
#plt.show()

# %%
plt.plot(rl, Outsource)
plt.title("Recovery Level vs. Cost of Outsourcing")
plt.xlabel("Recovery Level")
plt.ylabel("Cost of Outsourcing")
plt.show()

# %%
plt.plot(rl, LostSales)
plt.title("Recovery Level vs. Cost of Lost Sales")
plt.xlabel("Recovery Level")
plt.ylabel("Cost of Lost Sales")
plt.show()

# %%
plt.plot(rl, RL_Penalties)
plt.title("Recovery Level vs. Penalties")
plt.xlabel("Recovery Level")
plt.ylabel("Penalties")
plt.show()

# %%
## Costs against each other

# %%
plt.scatter(Outsource, LostSales)
plt.title("Cost of Outsourcing vs. Cost of Lost Sales")
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Lost Sales")
plt.show()

# %%
plt.scatter(Outsource, RL_Penalties)
plt.title("Cost of Outsourcing vs. Penalties")
plt.xlabel("Cost of Outsourcing")
plt.ylabel("Cost of Penalties")
plt.show()

# %%
plt.scatter(LostSales, RL_Penalties)
plt.title("Cost of Lost Sales vs. Penalties")
plt.xlabel("Cost of Lost Sales")
plt.ylabel("Cost of Penalties")
plt.show()
